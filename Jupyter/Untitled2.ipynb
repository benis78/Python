# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import os
dfo = os.path.join('D:/Dropbox/Coding/CompareExcel/Files/', '1234-401-001-- - Test-BOM.xlsx')
dfn = os.path.join('D:/Dropbox/Coding/CompareExcel/Files/', '1234-401-001-A - Test-BOM.xlsx')
df = os.path.join('C:/Working Folder/Designs/5-Projects/2500 - Aabenraa/Area 99 - Common Area/','2500-499-001-- - PARTLIST.xlsx')
df=pd.read_excel(df)

# %%
df.head()
# Out:
#    Item   Part Number REV                   Filename  Stock Number  Thumbnail  \
# 0   181  0000-710-001   -  2500-04.7-BM010-01-01.ipt           NaN        NaN
# 1   172  0000-710-001   -  2500-04.7-BM007-02-01.ipt           NaN        NaN
# 2    64  0000-710-002   -    2500-99-BG086-01-02.ipt           NaN        NaN
# 3   157  0000-710-001   -  2500-04.7-BM001-01-01.ipt           NaN        NaN
# 4   104  0000-710-001   -    2500-99-BM040-01-01.ipt           NaN        NaN
#
#   BOM Structure                                        Description Material  \
# 0        Normal            PE100 Pipe - DN125-Ø140,0xSDR17 L=22190    PE100
# 1        Normal            PE100 Pipe - DN200-Ø225,0xSDR11 L=22140    PE100
# 2        Normal  PE100 Pipe - EN1555 - DN500-Ø500,0xSDR26 L=287954    PE100
# 3        Normal            PE100 Pipe - DN100-Ø125,0xSDR17 L=45794    PE100
# 4        Normal            PE100 Pipe - DN250-Ø280,0xSDR17 L=49933    PE100
#
# ...

# %%
for t in df['Description']:
    tt=t.rsplit(' L=')[0]
    for t1 in tt:
        lt=

# %%
g=df.groupby(['Filename'])
g.head()
# Out:
#      Item   Part Number REV                               Filename  \
# 0     181  0000-710-001   -              2500-04.7-BM010-01-01.ipt
# 1     172  0000-710-001   -              2500-04.7-BM007-02-01.ipt
# 2      64  0000-710-002   -                2500-99-BG086-01-02.ipt
# 3     157  0000-710-001   -              2500-04.7-BM001-01-01.ipt
# 4     104  0000-710-001   -                2500-99-BM040-01-01.ipt
# ..    ...           ...  ..                                    ...
# 186   202  0000-712-001   -                2500-01-TW120-02-02.ipt
# 187   203  0000-717-001   -                2500-01-TD069-01-01.ipt
# 188   204  0000-717-041   -  Equal Y Junction 45° - Ø160 - PVC.ipt
# 189   205  0000-717-030   -       Socket Bend 45° - Ø160 - PVC.ipt
# 190   206  0000-717-030   -     Socket Bend 88,5° - Ø160 - PVC.ipt
#
#      Stock Number  Thumbnail BOM Structure  \
# 0             NaN        NaN        Normal
# 1             NaN        NaN        Normal
# ...
