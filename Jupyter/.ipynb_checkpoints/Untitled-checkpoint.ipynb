# %%
import pandas as pd

file_path='D:\Dropbox\Coding\Jupyter\BOM.xlsx'

data=pd.read_excel(file_path,sheet_name='BOM',header=0)


data['Parrent']=data.Item.str.rpartition('.')[0]
d=data.Item.str.rpartition('.')[0]


for i in data['Item'] :
    #data['Hit'] = data.loc[data['Item']==i, 'QTY']*2#.index[0]
    data['Hit'] = data["Item"].str.fullmatch(i)

# dropping null value columns to avoid errors 
#data.dropna(inplace = True) 

# substring to be searched 
#sub = '1.1'

  
# creating and passsing series to new column 
#data['hit'] = data["Item"].str.fullmatch(sub)

data
# Out:
#        Item       Part Number                                     Description  \
# 0         1      2500-404-006                                   Digester Area
# 1       1.1  2500-04-BG062-12                        Biogas pipe - DN250 - BG
# 2     1.1.1      0000-703-010           Collar - DN250/PN6 - EN 1092-1 Typ 37
# 3     1.1.2      0000-703-020  Pressed Flange - DN250/PN10 - EN 1092-1 Typ 02
# 4     1.1.3      0000-703-001     Pipe - DN250-Ø273,0x2,0 L=39475 - EN10217-7
# ...     ...               ...                                             ...
# 1505   28.1      0000-703-075                Elbow 90° DN10 G⅜ - DIN EN 10241
# 1506   28.2      0000-701-001       Ball valve - DN10 - manual - Valtor V-106
# 1507   28.3      0000-701-011       Air Relief Valve - G⅜ - Flexvent - Flamco
# 1508   28.4      0000-703-062              Hexagon Nipple - G⅜ - DIN EN 10241
# 1509   28.5      0000-316-010                     4 HEX Water-Biomass Ver. 01
#
#                       Title                Material  \
# 0                   Area 04                     NaN
# 1     Area 04 - Digester 12                     NaN
# 2                       NaN  SS 1.4571 - AISI 316Ti
# 3                       NaN    SS 1.4301 - AISI 304
# 4                       NaN  SS 1.4571 - AISI 316Ti
# ...                     ...                     ...
# 1505                    NaN               SS 1.4408
# 1506                    NaN   SS 1.4404 - AISI 316L
# 1507                    NaN                       -
# 1508                    NaN               SS 1.4408
# 1509                    NaN    SS 1.4301 - AISI 304
#
#                                                Filename BOM Structure QTY  \
# 0                                      2500-404-006.iam        Normal   1
# 1                                  2500-04-BG062-12.iam        Normal   1
# 2      Collar DN250 - PN6 EN 1092-1 Typ 37 - 1.4571.ipt     Purchased  21
# 3     Pressed Flanges - DN250 PN10 - EN 1092-1 Typ 0...     Purchased  21
# 4                               2500-04-BG033-12-01.ipt        Normal   1
# ...                                                 ...           ...  ..
# 1505               Elbow 90° DN10 G⅜ - DIN EN 10241.ipt     Purchased   4
# 1506      Ball valve - DN10 - manual - Valtor V-106.ipt        Normal   4
# 1507      Air Relief Valve - G⅜ - Flexvent - Flamco.ipt     Purchased   4
# 1508    Hexagon Nipple - DIN EN 10241 - G⅜ - 1.4408.ipt     Purchased   4
# 1509                                   0000-316-010.ipt        Normal   1
#
#       REV Drawing on Server Parrent    Hit
# 0       -               PDF          False
# 1       -               PDF       1  False
# 2     NaN     Not available     1.1  False
# 3     NaN     Not available     1.1  False
# 4       -     Not available     1.1  False
# ...   ...               ...     ...    ...
# 1505  NaN     Not available      28  False
# 1506  NaN     Not available      28  False
# 1507  NaN     Not available      28  False
# 1508    -     Not available      28  False
# 1509  NaN               PDF      28   True
#
# [1510 rows x 12 columns]

# %%
data.loc[data['Item']=='28.1', 'QTY']2#.index[0]
# Out:
# 1505    8
# Name: QTY, dtype: object

# %%
lastchar=data.Item.str.rfind(".")
lastchar.astype(int)
lastchar

#stripdata = data['Item'].map(lambda x: x.lstrip('1'))
stripdata=data['Item'].map(lambda x: x[:-1])
stripdata

last=data.Item.str.rfind(".").astype(int)
strip=data.Item.str.slice(last,-2,1)
strip
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1505   NaN
# 1506   NaN
# 1507   NaN
# 1508   NaN
# 1509   NaN
# Name: Item, Length: 1510, dtype: float64
