# %%
data = {
    'Item': ['1','1.1','1.1.1','1.1.2','1.1.2.1','2'],
    'QTY': ['2','3','4','2','2','1']
    }

# Convert string to int
qty=[int(i) for i in data['QTY']]

# Get parent level
ps=[i.rsplit('.', 1)[0] for i in data['Item']]
#print(type(ps[0]))
pp=[i.rpartition('.')[0] for i in data['Item']]
#print(type(pp[0]))
#conditions = [
#    if pp == '':
#       data['Item']=data['QTY']
#]

ii=[data['Item'].index(i) for i in ps]
print(ii)


#print(type(ii[1]))
#totalQTY=[]
#for i in pp:
#    if i=='':
#        qt.append(qty[i])
#    else:
#        data['Item'].index(i)
        

#test=[]
#for i in ii:
#    test.append(qty[i])
    #print(i)
#print(test)

qt=[]
e=0
for i in pp:
    if i =='':
        qt.append(qty[e])
        #print(i)
    else:
        qt.append(qty[e]*qt[ii[e]])
    #else:
    #    qt.append(ii[e]*qty[e])
    #    #print(test[e])
    e+=1
   
#print(qty[ii[8]])
#print(ps)
#print(ii)
print(qt)
# Out:
# [0, 0, 1, 1, 3, 5]
# [2, 6, 24, 12, 24, 1]

# %%
subs = 2400
likes = 200
comments = 56

conditions = [
    subs > 150,
    likes > 150,
    comments >50
]

if all(conditions):
    print('Awesome video')
# Out:
# Awesome video
