# %%
import pandas as pd

file_path='D:\Dropbox\Coding\Jupyter\BOM.xlsx'

data=pd.read_excel(file_path,sheet_name='BOM',header=0)

data['QTY'] = data['QTY'].astype(str)

res = [int(ele) if ele.isdigit() else int(ele.rsplit(',', 1)[0]) for ele in data['QTY']]  

print(data['Item'])

# Convert ITEM to String
#data['Item']= data['Item'].astype(str)

#res = data['QTY'][3].str.isdigit()
#print(data['Item'])
data['Parrent']=data.Item.str.rpartition('.')[0]
#d=data.Item.str.rpartition('.')[0]
#print(data[('Item')])
for p in data.Item:
    pv = data.Item.str.rpartition('.')[0]
    


# dropping null value columns to avoid errors 
#data.dropna(inplace = True) 

# substring to be searched 
#sub = '1.1'

  
# creating and passsing series to new column 
#data['hit'] = data["Item"].str.fullmatch(sub)

#print(res)
# Out:
# 0       1.0
# 1       1.1
# 2       1.2
# 3       1.3
# 4       1.4
#        ...
# 144    28.3
# 145    28.4
# 146    28.5
# 147    28.6
# 148    28.7
# Name: Item, Length: 149, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1b47eb54c085> in <module>
#      16 #res = data['QTY'][3].str.isdigit()
#      17 #print(data['Item'])
# ---> 18 data['Parrent']=data.Item.str.rpartition('.')[0]
#      19 #d=data.Item.str.rpartition('.')[0]
#      20 #print(data[('Item')])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...

# %%
data.loc[data['Item']=='28.1', 'QTY']2#.index[0]
# Out:
#   File "<ipython-input-4-d012bdfda5f5>", line 1
#     data.loc[data['Item']=='28.1', 'QTY']2#.index[0]
#                                          ^
# SyntaxError: invalid syntax

# %%
lastchar=data.Item.str.rfind(".")
lastchar.astype(int)
lastchar

#stripdata = data['Item'].map(lambda x: x.lstrip('1'))
stripdata=data['Item'].map(lambda x: x[:-1])
stripdata

last=data.Item.str.rfind(".").astype(int)
strip=data.Item.str.slice(last,-2,1)
strip
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1505   NaN
# 1506   NaN
# 1507   NaN
# 1508   NaN
# 1509   NaN
# Name: Item, Length: 1510, dtype: float64

# %%
data.Item, data.QTY
# Out:
# (0           1
#  1         1.1
#  2       1.1.1
#  3       1.1.2
#  4       1.1.3
#          ...
#  1505     28.1
#  1506     28.2
#  1507     28.3
#  1508     28.4
#  1509     28.5
#  Name: Item, Length: 1510, dtype: object,
#  0        1
#  1        1
#  2       21
#  3       21
#  4        1
#          ..
#  1505     4
#  1506     4
#  1507     4
#  1508     4
#  1509     1
#  Name: QTY, Length: 1510, dtype: object)
